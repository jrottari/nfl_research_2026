# %%
import pandas as pd
personal_forecast = pd.read_csv("C:/Users/user/repos/nfl_research_2026/data/exports/2026_ppr_forecast_tier1_xgboost.csv")
harris_forecast = pd.read_csv("C:/Users/user/Downloads/big board - harris_football ranks.csv")
merged = pd.merge(harris_forecast, personal_forecast, left_on=["name"], right_on=["player_name"], how="outer")
merged.to_csv('C:/Users/user/Downloads/personal_model_and_harris.csv', index=False)
